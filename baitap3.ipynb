# %%
from PIL import Image
from toolimage import *
from IPython.display import display

# %%
dir = 'C:/Users/nhutp/Documents/thigiacmaytinh/img/anh1.jpg'

# %%
img = load_image(dir)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x423>

# %%
print(img.size)
# Out:
# (550, 423)

# %%
new_size = (300,200)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x200>

# %%
luuanhmoi = dir + "luuanhmoi.jpg"
img.save(luuanhmoi)
