# %%
from PIL import Image
from toolimage import *
from IPython.display import display # to display images

# %%
dir = 'C:/Users/nhutp/Documents/thigiacmaytinh/img'

# %%
imgs =  get_image_list(dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (550, 423)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x423>
# (612, 443)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x443>
# (550, 423)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x423>
# (550, 423)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=550x423>
