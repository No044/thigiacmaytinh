# %%
# Import lớp Image
from PIL import Image
from toolimage import *
from IPython.display import display # to display images

# %%
# Đường dẫn ảnh
my_path = 'C:/Users/nhutp/Documents/thigiacmaytinh/img/anh1.jpg'
# Đọc ảnh 
img = load_image(my_path)

# Resize
# img = img.resize((250,250))
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x423>

# %%
# Xoay ảnh
rotated_image = img.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=550x423>

# %%
rotated_image = rotated_image.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=550x423>

# %%
# Transpose ảnh
transposed_image = img.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=423x550>

# %%
# Transpose ảnh
transposed_image = transposed_image.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=550x423>
